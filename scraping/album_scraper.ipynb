# %%
import pandas as pd
import spotipy
import time
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy import SpotifyException
from urllib.request import urlretrieve
import os
from ratelimit import limits, sleep_and_retry
import traceback
import requests

# %%
# Initialize Spotipy client credentials managers
client_credentials_manager = SpotifyClientCredentials(client_id='',
                                                         client_secret='')

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
df = pd.read_csv('bands_by_genre.csv')
print(df.shape)
df = df.drop_duplicates(subset='band_name')
print(df.shape)
df.to_csv('bands_by_genre.csv')
# Out:
# (6333, 8)
# (6333, 8)

# %%
# Create a custom session with a longer timeout value (e.g., 60 seconds)
session = requests.Session()
session.mount('https://', requests.adapters.HTTPAdapter(pool_connections=1, pool_maxsize=1, max_retries=3, pool_block=True))
session.timeout = 60

def download_image(url, directory, filename):
    # Create directory if it doesn't exist
    os.makedirs(directory, exist_ok=True)

    # Replace invalid characters in the filename
    filename = "".join(c if c.isalnum() or c in {' ', '_', '-', '.'} else '_' for c in filename.strip())

    # Save the image to the specified directory with the given filename
     # Save the image to the specified directory with the given filename
    filepath = os.path.join(directory, filename)
    try:
        urlretrieve(url, filepath)
    except Exception as e:
        print(f"Error downloading image for {filename}: {e}")
        traceback.print_exc()
    else:
        return filepath

processed = pd.read_csv('albums.csv')
processed_bands = set(processed['band_name'])  # Convert to a set for faster lookup

# Decorator for rate limiting
@sleep_and_retry
@limits(calls=160, period=60)  # Adjust rate limit as per Spotify API limits
def call_spotify_api(func, *args, **kwargs):
    try:
        return func(*args, **kwargs)
    except requests.exceptions.Timeout:
        print("Request timed out, retrying...")
        time.sleep(10)  # Wait for 10 seconds before retrying
        return call_spotify_api(func, *args, **kwargs)

df = pd.read_csv('bands_by_genre_id.csv')
chunklist = []
start, end, step = 0, len(df['band_id']), 100
for i in range(start, end, step):
    chunklist.append(df['band_id'][i: i + step])

dct = {
    'genre': [],
    'band_name': [],
    'album_name': [],
    'album_release_date': [],
    'album_id': [],
}

for index, chunk in enumerate(chunklist):
    for artist_id in chunk:
        try:
            band_name = df.loc[df['band_id'] == artist_id, 'band_name'].values[0]
            if band_name in processed_bands:
                continue

            albums = call_spotify_api(sp.artist_albums, artist_id)
            if albums['items']:
                for album in albums['items']:
                    if album['album_type'] == 'album':
                        genre = df.loc[df['band_id'] == artist_id, 'genre'].values[0]
                        dct['genre'].append(genre)
                        dct['band_name'].append(band_name)
                        dct['album_name'].append(album['name'])
                        dct['album_release_date'].append(album['release_date'])
                        dct['album_id'].append(album['id'])

                        if album['images']:
                            url = album['images'][0]['url']
                            filename = f"{band_name}_{album['name']}.jpg"
                            sanitized_genre = "".join(c for c in genre if c.isalnum() or c in {' ', '_', '-'}).strip()
                            directory = os.path.join("data", sanitized_genre)
                            download_image(url, directory, filename)
                        time.sleep(0.5)  # Add a short delay between album downloads
        

        except (SpotifyException, ConnectionError) as e:
            print(f"Error occurred at index {index}: {e}")
            time.sleep(10)
            continue
    print(band_name)
    # Append the band IDs to the list and create a DataFrame with an index
    albumdf = pd.DataFrame(dct)

    # Append to albums2.csv instead of overwriting
    
    albumdf.to_csv('albums2.csv', mode='a', index=False, header=not os.path.exists('albums2.csv'))
TChjWrnXHrk5NyBU', '2PSXyiERCaNmRyFA06UMjq', '0qbV4e18lWrTTxlswVoLbI', '09VNOLsjKwQasQXhsS8sRA', '2VTJaQNkvxU4S2zjkVJirF', '7MtBapy0MnmBVsU3o0yrFz', '5ZTSBNqk3wDvhgN12c2ECP', '4qsVHamREe2Vpfur0jczkR', '1vy3wxf8GbW7DBSfxPDKBM', '42TNtAEG1xM0bLTVGMl6gb', '7q7uolRH6h7tWETTTUmjPI', '4CO6V2Nkr7gQCXwfuJuUDm', '5eBEBLKwazqvkfk9uvqvLh', '3J4ZZ83PrVqPgN7KY6jn4S', '2J3XzDLjbXkny8qhr33zTh', '5JAnXx5BBES4FEf4d4t4CC', '4hjTm9cn9ZPwfKnbyW6frn', '6xFoN6e5B9DTw6aV6yT3KF', '105mv6XqVQMEUVfPkIeAQh', '3zG3x7RA9DjR7a9JMNWv1N', '6ATqmUzk4xbq3XpVsZMPW5', '0nP2Se8dSKsdOkg6XEee60', '2lJhUIQR7CYQZD6tyl3aF0', '7ucFoRbiHn7SOVfHFHRjbE', '61MvWKeLK4tjdSuuB8y8B8', '3RlKO1La6qRZp4qWVpZCPp', '7vxLun2SVGuJII6DkbyMso', '4zfEDLbmmI7V9Yt12s0DQH', '3wHjbDGFrHN17FWg4owTkc', '4y9IRABVc2TzATl8mTkexk', '6z8LLgG81xuNzqJO5XjWPP', '4lmSiv5xEJJZsO40XtSK1J', '2UIuYNBg8r5pkoG2MjdLZT', '1WgzDxuLr7iCKLKHGcygql', '3I4tEaOcF0wtl6179DqbZb', '7c7z3Ep51f2LIANMPRH55h', '5jEfQZmmwwKymr9cfmgfsd', '4GVS3i2hzZZaL1OZigNafO', '1JOkHtzr0DBLFKpccLO5Yq', '5kfSRmjf9aSougnHL6KgLH']
)
print(test)
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 429 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\MKnaepen\Documents\BeCode\projects\metal classifier\venv\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\MKnaepen\Documents\BeCode\projects\metal classifier\venv\Lib\site-packages\urllib3\connectionpool.py:948, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     947     log.debug("Retry: %s", url)
# --> 948     return self.urlopen(
#     949         method,
#     950         url,
#     951         body,
#     952         headers,
#     953         retries=retries,
#     954         redirect=redirect,
#     955         assert_same_host=assert_same_host,
#     956         timeout=timeout,
#     957         pool_timeout=pool_timeout,
#     958         release_conn=release_conn,
#     959         chunked=chunked,
#     960         body_pos=body_pos,
#     961         preload_content=preload_content,
#     962         decode_content=decode_content,
#     963         **response_kw,
#     964     )
#     966 return response
#
# File c:\Users\MKnaepen\Documents\BeCode\projects\metal classifier\venv\Lib\site-packages\urllib3\connectionpool.py:948, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     947     log.debug("Retry: %s", url)
# --> 948     return self.urlopen(
#     949         method,
#     950         url,
#     951         body,
#     952         headers,
#     953         retries=retries,
#     954         redirect=redirect,
#     955         assert_same_host=assert_same_host,
#     956         timeout=timeout,
#     957         pool_timeout=pool_timeout,
#     958         release_conn=release_conn,
#     959         chunked=chunked,
#     960         body_pos=body_pos,
#     961         preload_content=preload_content,
#     962         decode_content=decode_content,
#     963         **response_kw,
#     964     )
#     966 return response
#
# File c:\Users\MKnaepen\Documents\BeCode\projects\metal classifier\venv\Lib\site-packages\urllib3\connectionpool.py:948, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     947     log.debug("Retry: %s", url)
# --> 948     return self.urlopen(
#     949         method,
#     950         url,
#     951         body,
#     952         headers,
#     953         retries=retries,
#     954         redirect=redirect,
#     955         assert_same_host=assert_same_host,
#     956         timeout=timeout,
#     957         pool_timeout=pool_timeout,
#     958         release_conn=release_conn,
#     959         chunked=chunked,
#     960         body_pos=body_pos,
#     961         preload_content=preload_content,
#     962         decode_content=decode_content,
#     963         **response_kw,
#     964     )
#     966 return response
#
# File c:\Users\MKnaepen\Documents\BeCode\projects\metal classifier\venv\Lib\site-packages\urllib3\connectionpool.py:938, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     937 try:
# --> 938     retries = retries.increment(method, url, response=response, _pool=self)
#     939 except MaxRetryError:
#
# File c:\Users\MKnaepen\Documents\BeCode\projects\metal classifier\venv\Lib\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=3uSATa7xWXVJrMhJJSnGGk,5iG1GycXpheJ5xMW0gNvKv,2hBn08QphNtdnhwDNtnZMg,6HeYgpgqEo8SGis4dHwRbu,1ALXFmNr7lrTug2LAE989q,6eXWc7irALyENtbAD2TTOT,6eiFVKWhv9EYL2RdrVFtyC,0aHwh2rqyJNN0eZ4sGZLEt,1oCQLSGSiHozdyx7lOqkIt,2ZPnedMaS4W1de05Xz18hF,3L82LuRzu60EPSK1yf5Pxr,589aAz8258JEsMwpJglalU,4qAakbD2wRBjnKxlU8EywU,2bvRtBoXOc1eeMQ9xQRuif,0kNrZfKZMvqxK36pUeB4wX,5icLTeOSXTvkLIi08P2k4g,5OxoeZOWZTMj06cPftX1Iz,74ipwWk1JxGtqZjKNq57rm,27oBnGKPph4BtZKKjd9b2j,1nwQ9wWcGjAQt4u65AKkbk,4HcGbZ4n4j1rObwTmix9Ca,5pEBCke4Ft8N5v8jww1eUn,5jMMdrSIAGueAxfeI1AG5K,5PNXZX1QUeae7WjsCfycwc,3LGrbnTyEszZ8JlWLFnznz,0YSoqT8eVDJFIui9PR4aGk,0zKAEqyCG1nudg3bFRrZvt,4yE0IGEKGGd1w2rWlUywK8,57ou3Gno3QiWTuyOqMC0aS,12yBSkAxdEFXFkclZ8wc8S,5cpoALsvCDLvrpuuVZb6gH,78OYMU05t1YJUHyOmGM2su,4nvFgshg9sO9YVnlKgQysN,0F0lB96kMC1BRDkjvgMiWG,10qHfyQqzsbBDwob8nk8Ol,6fjer7Ed6ZUna1EMbwbDrN,2NBvvx52QAjipBnXvAekfs,3JjZq20Kv6UphyyirAaY9A,1dzmb0UZZatm5VCD8fI8UF,0dcFoXAFWxx7oSIIq2mtkW,3m8zeHjUKHDVHbx5JmS2qx,4IuzY8RNrCGPIchltRMWzz,4Ixe61Sv0WlxBhDjRtEgH3,5EA75qDylWv25sjzyM1BOa,1CNCFVas53ePcTa6xjMhoF,3eB1b4DL6O9TMOksOYg83l,4VSgmiMD3DGZXVtsVFZDB1,0xdqFv6Mvyg7qqyzU3NcpU,31zZc
9Mk,3BVJ1nwvdmYjXJ7gBTXTGX,13Uvqll8OQDjw3wDweIK9y,3e7wv9TChjWrnXHrk5NyBU,2PSXyiERCaNmRyFA06UMjq,0qbV4e18lWrTTxlswVoLbI,09VNOLsjKwQasQXhsS8sRA,2VTJaQNkvxU4S2zjkVJirF,7MtBapy0MnmBVsU3o0yrFz,5ZTSBNqk3wDvhgN12c2ECP,4qsVHamREe2Vpfur0jczkR,1vy3wxf8GbW7DBSfxPDKBM,42TNtAEG1xM0bLTVGMl6gb,7q7uolRH6h7tWETTTUmjPI,4CO6V2Nkr7gQCXwfuJuUDm,5eBEBLKwazqvkfk9uvqvLh,3J4ZZ83PrVqPgN7KY6jn4S,2J3XzDLjbXkny8qhr33zTh,5JAnXx5BBES4FEf4d4t4CC,4hjTm9cn9ZPwfKnbyW6frn,6xFoN6e5B9DTw6aV6yT3KF,105mv6XqVQMEUVfPkIeAQh,3zG3x7RA9DjR7a9JMNWv1N,6ATqmUzk4xbq3XpVsZMPW5,0nP2Se8dSKsdOkg6XEee60,2lJhUIQR7CYQZD6tyl3aF0,7ucFoRbiHn7SOVfHFHRjbE,61MvWKeLK4tjdSuuB8y8B8,3RlKO1La6qRZp4qWVpZCPp,7vxLun2SVGuJII6DkbyMso,4zfEDLbmmI7V9Yt12s0DQH,3wHjbDGFrHN17FWg4owTkc,4y9IRABVc2TzATl8mTkexk,6z8LLgG81xuNzqJO5XjWPP,4lmSiv5xEJJZsO40XtSK1J,2UIuYNBg8r5pkoG2MjdLZT,1WgzDxuLr7iCKLKHGcygql,3I4tEaOcF0wtl6179DqbZb,7c7z3Ep51f2LIANMPRH55h,5jEfQZmmwwKymr9cfmgfsd,4GVS3i2hzZZaL1OZigNafO,1JOkHtzr0DBLFKpccLO5Yq,5kfSRmjf9aSougnHL6KgLH:
#  Max Retries, reason: too many 429 error responses

# %%
# Create a custom session with a longer timeout value (e.g., 60 seconds)
session = requests.Session()
session.mount('https://', requests.adapters.HTTPAdapter(pool_connections=1, pool_maxsize=1, max_retries=3, pool_block=True))
session.timeout = 60

def download_preview(url, directory, filename):
    counter = 0
    # Create directory if it doesn't exist
    os.makedirs(directory, exist_ok=True)

    # Save the preview with the track_id as the filename
    filepath = os.path.join(directory, f"{filename}.mp3")
    try:
        urlretrieve(url, filepath)
        downloaded = 'Y'
    except Exception:
        counter +=1
        print(f'{counter} preview tracks not available')
        downloaded = 'N'
    else:
        return filepath, downloaded

def process_album(tracks, album_id):
    unavailable_count = 0
    if tracks['items']:
        genre = albums.loc[albums['album_id'] == album_id, 'genre'].values[0]
        band_name = albums.loc[albums['album_id'] == album_id, 'band_name'].values[0]
        album_name = albums.loc[albums['album_id'] == album_id, 'album_name'].values[0]
        
        genre_list = []
        band_name_list = []
        album_name_list = []
        album_id_list = []
        track_ids = []
        track_titles = []
        preview_urls = []
        preview_downloaded = []

        for track in tracks['items']:
            track_id = track['id']
            track_title = track['name']
            if (album_id, track_id) not in processed_tracks:
                track_ids.append(track_id)
                track_titles.append(track_title)
                genre_list.append(genre)
                band_name_list.append(band_name)
                album_name_list.append(album_name)
                album_id_list.append(album_id)
                if track['preview_url']:
                    preview_urls.append(track['preview_url'])
                    preview_downloaded.append('N')  # Initialize as 'N' and update later if downloaded successfully
                else:
                    unavailable_count += 1
                    preview_downloaded.append('N')

        for index, (track_id, url) in enumerate(zip(track_ids, preview_urls)):
            sanitized_genre = "".join(c for c in genre if c.isalnum() or c in {' ', '_', '-'}).strip()
            directory = os.path.join("data", sanitized_genre)
            result = download_preview(url, directory, track_id)
            if result:
                filepath, downloaded = result
                preview_downloaded[index] = downloaded

        dct['genre'].extend(genre_list)
        dct['band_name'].extend(band_name_list)
        dct['album_name'].extend(album_name_list)
        dct['album_id'].extend(album_id_list)
        dct['track_id'].extend(track_ids)
        dct['track_title'].extend(track_titles)
        dct['preview_downloaded'].extend(preview_downloaded)

        processed_tracks.update([(album_id, track_id) for track_id in track_ids])

        if unavailable_count > 0:
            print(f'{unavailable_count} preview tracks not available for {album_name} by {band_name}')

        time.sleep(0.5)  # Add a short delay between album downloads

albums = pd.read_csv('albums.csv')
processed = pd.read_csv('tracks.csv')
processed_albums = set(processed['album_id'])  # Convert to a set for faster lookup
processed_tracks = set(zip(processed['album_id'], processed['track_id']))  # Set of (album_id, track_id) tuples

# Decorator for rate limiting
@sleep_and_retry
@limits(calls=100, period=60)  # Adjust rate limit as per Spotify API limits
def call_spotify_api(func, *args, **kwargs):
    try:
        return func(*args, **kwargs)
    except requests.exceptions.Timeout:
        print("Request timed out, retrying...")
        time.sleep(10)  # Wait for 10 seconds before retrying
        return call_spotify_api(func, *args, **kwargs)

chunklist = []
start, end, step = 0, len(albums['album_id']), 20
for i in range(start, end, step):
    chunklist.append(albums['album_id'][i: i + step])

dct = {
    'genre': [],
    'band_name': [],
    'album_name': [],
    'album_id': [],
    'track_title':[],
    'track_id':[],
    'preview_downloaded': []
}

for index, chunk in enumerate(chunklist):
    for album_id in chunk:
        if album_id not in processed_albums:
            try:       
                album_tracks = call_spotify_api(sp.album_tracks, album_id)
                process_album(album_tracks, album_id)
                   
            except (SpotifyException, ConnectionError) as e:
                print(f"Error occurred at index {index}: {e}")
                time.sleep(10)
                continue

    # Create a new DataFrame from the dct dictionary
    trackdf = pd.DataFrame(dct)

    # Drop duplicate rows based on 'album_id' and 'track_id' columns
    trackdf.drop_duplicates(subset=['album_id', 'track_id'], inplace=True)

    # Save the DataFrame to CSV, appending to the existing file
    trackdf.to_csv('tracks.csv', mode='a', index=False, header=not os.path.exists('tracks.csv'))
    print(f'progress saved chunk {index}/{len(chunklist)}')

    # Reset the dct dictionary to avoid duplicates in the next chunk
    for key in dct.keys():
        dct[key] = []

# Save the final DataFrame to CSV
trackdf = pd.DataFrame(dct)
trackdf.drop_duplicates(subset=['album_id', 'track_id'], inplace=True)
trackdf.to_csv('tracks.csv', mode='a', index=False, header=not os.path.exists('tracks.csv'))
print('Album scraping completed')
# Out:
# progress saved chunk 0/1221
# progress saved chunk 1/1221
# progress saved chunk 2/1221
# progress saved chunk 3/1221
# progress saved chunk 4/1221
# progress saved chunk 5/1221
# progress saved chunk 6/1221
# progress saved chunk 7/1221
# progress saved chunk 8/1221
# progress saved chunk 9/1221
# progress saved chunk 10/1221
# progress saved chunk 11/1221
# progress saved chunk 12/1221
# progress saved chunk 13/1221
# progress saved chunk 14/1221
# progress saved chunk 15/1221
# progress saved chunk 16/1221
# progress saved chunk 17/1221
# progress saved chunk 18/1221
# progress saved chunk 19/1221
# progress saved chunk 20/1221
# progress saved chunk 21/1221
# progress saved chunk 22/1221
# progress saved chunk 23/1221
# progress saved chunk 24/1221
# progress saved chunk 25/1221
# progress saved chunk 26/1221
# progress saved chunk 27/1221
# progress saved chunk 28/1221
# progress saved chunk 29/1221
# progress saved chunk 30/1221
# progress saved chunk 31/1221
# progress saved chunk 32/1221
# progress saved chunk 33/1221
# progress saved chunk 34/1221
# progress saved chunk 35/1221
# progress saved chunk 36/1221
# progress saved chunk 37/1221
# progress saved chunk 38/1221
# progress saved chunk 39/1221
# progress saved chunk 40/1221
# progress saved chunk 41/1221
# progress saved chunk 42/1221
# progress saved chunk 43/1221
# progress saved chunk 44/1221
# progress saved chunk 45/1221
# progress saved chunk 46/1221
# progress saved chunk 47/1221
# progress saved chunk 48/1221
# progress saved chunk 49/1221
# progress saved chunk 50/1221
# progress saved chunk 51/1221
# progress saved chunk 52/1221
# progress saved chunk 53/1221
# progress saved chunk 54/1221
# progress saved chunk 55/1221
# progress saved chunk 56/1221
# progress saved chunk 57/1221
# progress saved chunk 58/1221
# progress saved chunk 59/1221
# progress saved chunk 60/1221
# progress saved chunk 61/1221
# progress saved chunk 62/1221
# progress saved chunk 63/1221
# progress saved chunk 64/1221
# progress saved chunk 65/1221
# progress saved chunk 66/1221
# progress saved chunk 67/1221
# progress saved chunk 68/1221
# progress saved chunk 69/1221
# progress saved chunk 70/1221
# progress saved chunk 71/1221
# progress saved chunk 72/1221
# progress saved chunk 73/1221
# progress saved chunk 74/1221
# progress saved chunk 75/1221
# progress saved chunk 76/1221
# progress saved chunk 77/1221
# progress saved chunk 78/1221
# progress saved chunk 79/1221
# progress saved chunk 80/1221
# progress saved chunk 81/1221
# progress saved chunk 82/1221
# progress saved chunk 83/1221
# progress saved chunk 84/1221
# progress saved chunk 85/1221
# progress saved chunk 86/1221
# progress saved chunk 87/1221
# progress saved chunk 88/1221
# progress saved chunk 89/1221
# progress saved chunk 90/1221
# progress saved chunk 91/1221
# progress saved chunk 92/1221
# progress saved chunk 93/1221
# progress saved chunk 94/1221
# progress saved chunk 95/1221
# progress saved chunk 96/1221
# progress saved chunk 97/1221
# progress saved chunk 98/1221
# progress saved chunk 99/1221
# progress saved chunk 100/1221
# progress saved chunk 101/1221
# progress saved chunk 102/1221
# progress saved chunk 103/1221
# progress saved chunk 104/1221
# progress saved chunk 105/1221
# progress saved chunk 106/1221
# progress saved chunk 107/1221
# progress saved chunk 108/1221
# progress saved chunk 109/1221
# progress saved chunk 110/1221
# progress saved chunk 111/1221
# progress saved chunk 112/1221
# progress saved chunk 113/1221
# progress saved chunk 114/1221
# progress saved chunk 115/1221
# progress saved chunk 116/1221
# progress saved chunk 117/1221
# progress saved chunk 118/1221
# progress saved chunk 119/1221
# progress saved chunk 120/1221
# progress saved chunk 121/1221
# progress saved chunk 122/1221
# progress saved chunk 123/1221
# progress saved chunk 124/1221
# progress saved chunk 125/1221
# progress saved chunk 126/1221
# progress saved chunk 127/1221
# progress saved chunk 128/1221
# progress saved chunk 129/1221
# progress saved chunk 130/1221
# progress saved chunk 131/1221
# progress saved chunk 132/1221
# progress saved chunk 133/1221
# progress saved chunk 134/1221
# progress saved chunk 135/1221
# progress saved chunk 136/1221
# progress saved chunk 137/1221
# progress saved chunk 138/1221
# progress saved chunk 139/1221
# progress saved chunk 140/1221
# progress saved chunk 141/1221
# progress saved chunk 142/1221
# progress saved chunk 143/1221
# progress saved chunk 144/1221
# progress saved chunk 145/1221
# progress saved chunk 146/1221
# progress saved chunk 147/1221
# progress saved chunk 148/1221
# progress saved chunk 149/1221
# progress saved chunk 150/1221
# progress saved chunk 151/1221
# progress saved chunk 152/1221
# progress saved chunk 153/1221
# progress saved chunk 154/1221
# progress saved chunk 155/1221
# progress saved chunk 156/1221
# progress saved chunk 157/1221
# progress saved chunk 158/1221
# progress saved chunk 159/1221
# progress saved chunk 160/1221
# progress saved chunk 161/1221
# progress saved chunk 162/1221
# progress saved chunk 163/1221
# progress saved chunk 164/1221
# progress saved chunk 165/1221
# progress saved chunk 166/1221
# progress saved chunk 167/1221
# progress saved chunk 168/1221
# progress saved chunk 169/1221
# progress saved chunk 170/1221
# progress saved chunk 171/1221
# progress saved chunk 172/1221
# progress saved chunk 173/1221
# progress saved chunk 174/1221
# progress saved chunk 175/1221
# progress saved chunk 176/1221
# progress saved chunk 177/1221
# progress saved chunk 178/1221
# progress saved chunk 179/1221
# progress saved chunk 180/1221
# progress saved chunk 181/1221
# progress saved chunk 182/1221
# progress saved chunk 183/1221
# progress saved chunk 184/1221
# progress saved chunk 185/1221
# progress saved chunk 186/1221
# progress saved chunk 187/1221
# progress saved chunk 188/1221
# progress saved chunk 189/1221
# progress saved chunk 190/1221
# progress saved chunk 191/1221
# progress saved chunk 192/1221
# progress saved chunk 193/1221
# progress saved chunk 194/1221
# progress saved chunk 195/1221
# progress saved chunk 196/1221
# progress saved chunk 197/1221
# progress saved chunk 198/1221
# progress saved chunk 199/1221
# progress saved chunk 200/1221
# progress saved chunk 201/1221
# progress saved chunk 202/1221
# progress saved chunk 203/1221
# progress saved chunk 204/1221
# progress saved chunk 205/1221
# progress saved chunk 206/1221
# progress saved chunk 207/1221
# progress saved chunk 208/1221
# progress saved chunk 209/1221
# progress saved chunk 210/1221
# progress saved chunk 211/1221
# progress saved chunk 212/1221
# progress saved chunk 213/1221
# progress saved chunk 214/1221
# progress saved chunk 215/1221
# progress saved chunk 216/1221
# progress saved chunk 217/1221
# progress saved chunk 218/1221
# progress saved chunk 219/1221
# progress saved chunk 220/1221
# progress saved chunk 221/1221
# progress saved chunk 222/1221
# progress saved chunk 223/1221
# progress saved chunk 224/1221
# progress saved chunk 225/1221
# progress saved chunk 226/1221
# progress saved chunk 227/1221
# progress saved chunk 228/1221
# progress saved chunk 229/1221
# progress saved chunk 230/1221
# progress saved chunk 231/1221
# progress saved chunk 232/1221
# progress saved chunk 233/1221
# progress saved chunk 234/1221
# progress saved chunk 235/1221
# progress saved chunk 236/1221
# progress saved chunk 237/1221
# progress saved chunk 238/1221
# progress saved chunk 239/1221
# progress saved chunk 240/1221
# progress saved chunk 241/1221
# progress saved chunk 242/1221
# progress saved chunk 243/1221
# progress saved chunk 244/1221
# progress saved chunk 245/1221
# progress saved chunk 246/1221
# progress saved chunk 247/1221
# progress saved chunk 248/1221
# progress saved chunk 249/1221
# progress saved chunk 250/1221
# progress saved chunk 251/1221
# progress saved chunk 252/1221
# progress saved chunk 253/1221
# progress saved chunk 254/1221
# progress saved chunk 255/1221
# progress saved chunk 256/1221
# progress saved chunk 257/1221
# progress saved chunk 258/1221
# progress saved chunk 259/1221
# progress saved chunk 260/1221
# progress saved chunk 261/1221
# progress saved chunk 262/1221
# progress saved chunk 263/1221
# progress saved chunk 264/1221
# progress saved chunk 265/1221
# progress saved chunk 266/1221
# progress saved chunk 267/1221
# progress saved chunk 268/1221
# progress saved chunk 269/1221
# progress saved chunk 270/1221
# progress saved chunk 271/1221
# progress saved chunk 272/1221
# progress saved chunk 273/1221
# progress saved chunk 274/1221
# progress saved chunk 275/1221
# progress saved chunk 276/1221
# progress saved chunk 277/1221
# progress saved chunk 278/1221
# progress saved chunk 279/1221
# progress saved chunk 280/1221
# progress saved chunk 281/1221
# progress saved chunk 282/1221
# progress saved chunk 283/1221
# progress saved chunk 284/1221
# progress saved chunk 285/1221
# progress saved chunk 286/1221
# progress saved chunk 287/1221
# progress saved chunk 288/1221
# progress saved chunk 289/1221
# progress saved chunk 290/1221
# progress saved chunk 291/1221
# progress saved chunk 292/1221
# progress saved chunk 293/1221
# progress saved chunk 294/1221
# progress saved chunk 295/1221
# progress saved chunk 296/1221
# progress saved chunk 297/1221
# progress saved chunk 298/1221
# progress saved chunk 299/1221
# progress saved chunk 300/1221
# progress saved chunk 301/1221
# progress saved chunk 302/1221
# progress saved chunk 303/1221
# progress saved chunk 304/1221
# progress saved chunk 305/1221
# progress saved chunk 306/1221
# progress saved chunk 307/1221
# progress saved chunk 308/1221
# progress saved chunk 309/1221
# progress saved chunk 310/1221
# progress saved chunk 311/1221
# progress saved chunk 312/1221
# progress saved chunk 313/1221
# progress saved chunk 314/1221
# progress saved chunk 315/1221
# progress saved chunk 316/1221
# progress saved chunk 317/1221
# progress saved chunk 318/1221
# progress saved chunk 319/1221
# progress saved chunk 320/1221
# progress saved chunk 321/1221
# progress saved chunk 322/1221
# progress saved chunk 323/1221
# progress saved chunk 324/1221
# progress saved chunk 325/1221
# progress saved chunk 326/1221
# progress saved chunk 327/1221
# progress saved chunk 328/1221
# progress saved chunk 329/1221
# progress saved chunk 330/1221
# progress saved chunk 331/1221
# progress saved chunk 332/1221
# progress saved chunk 333/1221
# progress saved chunk 334/1221
# progress saved chunk 335/1221
# progress saved chunk 336/1221
# progress saved chunk 337/1221
# progress saved chunk 338/1221
# progress saved chunk 339/1221
# progress saved chunk 340/1221
# progress saved chunk 341/1221
# progress saved chunk 342/1221
# progress saved chunk 343/1221
# progress saved chunk 344/1221
# progress saved chunk 345/1221
# progress saved chunk 346/1221
# progress saved chunk 347/1221
# progress saved chunk 348/1221
# progress saved chunk 349/1221
# progress saved chunk 350/1221
# progress saved chunk 351/1221
# progress saved chunk 352/1221
# progress saved chunk 353/1221
# progress saved chunk 354/1221
# progress saved chunk 355/1221
# progress saved chunk 356/1221
# progress saved chunk 357/1221
# progress saved chunk 358/1221
# progress saved chunk 359/1221
# progress saved chunk 360/1221
# progress saved chunk 361/1221
# progress saved chunk 362/1221
# progress saved chunk 363/1221
# progress saved chunk 364/1221
# progress saved chunk 365/1221
# progress saved chunk 366/1221
# progress saved chunk 367/1221
# progress saved chunk 368/1221
# progress saved chunk 369/1221
# progress saved chunk 370/1221
# progress saved chunk 371/1221
# progress saved chunk 372/1221
# progress saved chunk 373/1221
# progress saved chunk 374/1221
# progress saved chunk 375/1221
# progress saved chunk 376/1221
# progress saved chunk 377/1221
# progress saved chunk 378/1221
# progress saved chunk 379/1221
# progress saved chunk 380/1221
# progress saved chunk 381/1221
# progress saved chunk 382/1221
# progress saved chunk 383/1221
# progress saved chunk 384/1221
# progress saved chunk 385/1221
# progress saved chunk 386/1221
# progress saved chunk 387/1221
# progress saved chunk 388/1221
# progress saved chunk 389/1221
# progress saved chunk 390/1221
# progress saved chunk 391/1221
# progress saved chunk 392/1221
# progress saved chunk 393/1221
# progress saved chunk 394/1221
# progress saved chunk 395/1221
# progress saved chunk 396/1221
# progress saved chunk 397/1221
# progress saved chunk 398/1221
# progress saved chunk 399/1221
# progress saved chunk 400/1221
# progress saved chunk 401/1221
# progress saved chunk 402/1221
# progress saved chunk 403/1221
# progress saved chunk 404/1221
# progress saved chunk 405/1221
# progress saved chunk 406/1221
# progress saved chunk 407/1221
# progress saved chunk 408/1221
# progress saved chunk 409/1221
# progress saved chunk 410/1221
# progress saved chunk 411/1221
# progress saved chunk 412/1221
# progress saved chunk 413/1221
# progress saved chunk 414/1221
# progress saved chunk 415/1221
# progress saved chunk 416/1221
# progress saved chunk 417/1221
# progress saved chunk 418/1221
# progress saved chunk 419/1221
# progress saved chunk 420/1221
# progress saved chunk 421/1221
# progress saved chunk 422/1221
# progress saved chunk 423/1221
# progress saved chunk 424/1221
# progress saved chunk 425/1221
# progress saved chunk 426/1221
# progress saved chunk 427/1221
# progress saved chunk 428/1221
# progress saved chunk 429/1221
# progress saved chunk 430/1221
# progress saved chunk 431/1221
# progress saved chunk 432/1221
# progress saved chunk 433/1221
# progress saved chunk 434/1221
# progress saved chunk 435/1221
# progress saved chunk 436/1221
# progress saved chunk 437/1221
# progress saved chunk 438/1221
# progress saved chunk 439/1221
# progress saved chunk 440/1221
# progress saved chunk 441/1221
# progress saved chunk 442/1221
# progress saved chunk 443/1221
# progress saved chunk 444/1221
# progress saved chunk 445/1221
# progress saved chunk 446/1221
# progress saved chunk 447/1221
# progress saved chunk 448/1221
# progress saved chunk 449/1221
# progress saved chunk 450/1221
# progress saved chunk 451/1221
# progress saved chunk 452/1221
# progress saved chunk 453/1221
# progress saved chunk 454/1221
# progress saved chunk 455/1221
# progress saved chunk 456/1221
# progress saved chunk 457/1221
# progress saved chunk 458/1221
# progress saved chunk 459/1221
# progress saved chunk 460/1221
# progress saved chunk 461/1221
# progress saved chunk 462/1221
# progress saved chunk 463/1221
# progress saved chunk 464/1221
# progress saved chunk 465/1221
# progress saved chunk 466/1221
# progress saved chunk 467/1221
# progress saved chunk 468/1221
# progress saved chunk 469/1221
# progress saved chunk 470/1221
# progress saved chunk 471/1221
# progress saved chunk 472/1221
# progress saved chunk 473/1221
# progress saved chunk 474/1221
# progress saved chunk 475/1221
# progress saved chunk 476/1221
# progress saved chunk 477/1221
# progress saved chunk 478/1221
# progress saved chunk 479/1221
# progress saved chunk 480/1221
# progress saved chunk 481/1221
# progress saved chunk 482/1221
# progress saved chunk 483/1221
# progress saved chunk 484/1221
# progress saved chunk 485/1221
# progress saved chunk 486/1221
# progress saved chunk 487/1221
# progress saved chunk 488/1221
# progress saved chunk 489/1221
# progress saved chunk 490/1221
# progress saved chunk 491/1221
# progress saved chunk 492/1221
# progress saved chunk 493/1221
# progress saved chunk 494/1221
# progress saved chunk 495/1221
# progress saved chunk 496/1221
# progress saved chunk 497/1221
# progress saved chunk 498/1221
# progress saved chunk 499/1221
# progress saved chunk 500/1221
# progress saved chunk 501/1221
# progress saved chunk 502/1221
# progress saved chunk 503/1221
# progress saved chunk 504/1221
# progress saved chunk 505/1221
# progress saved chunk 506/1221
# progress saved chunk 507/1221
# progress saved chunk 508/1221
# progress saved chunk 509/1221
# progress saved chunk 510/1221
# progress saved chunk 511/1221
# progress saved chunk 512/1221
# progress saved chunk 513/1221
# progress saved chunk 514/1221
# progress saved chunk 515/1221
# progress saved chunk 516/1221
# progress saved chunk 517/1221
# progress saved chunk 518/1221
# progress saved chunk 519/1221
# progress saved chunk 520/1221
# progress saved chunk 521/1221
# progress saved chunk 522/1221
# progress saved chunk 523/1221
# progress saved chunk 524/1221
# progress saved chunk 525/1221
# progress saved chunk 526/1221
# progress saved chunk 527/1221
# progress saved chunk 528/1221
# progress saved chunk 529/1221
# progress saved chunk 530/1221
# progress saved chunk 531/1221
# progress saved chunk 532/1221
# progress saved chunk 533/1221
# progress saved chunk 534/1221
# progress saved chunk 535/1221
# progress saved chunk 536/1221
# progress saved chunk 537/1221
# progress saved chunk 538/1221
# progress saved chunk 539/1221
# progress saved chunk 540/1221
# progress saved chunk 541/1221
# progress saved chunk 542/1221
# progress saved chunk 543/1221
# progress saved chunk 544/1221
# progress saved chunk 545/1221
# progress saved chunk 546/1221
# progress saved chunk 547/1221
# progress saved chunk 548/1221
# progress saved chunk 549/1221
# progress saved chunk 550/1221
# progress saved chunk 551/1221
# progress saved chunk 552/1221
# progress saved chunk 553/1221
# progress saved chunk 554/1221
# progress saved chunk 555/1221
# progress saved chunk 556/1221
# progress saved chunk 557/1221
# progress saved chunk 558/1221
# progress saved chunk 559/1221
# progress saved chunk 560/1221
# progress saved chunk 561/1221
# progress saved chunk 562/1221
# progress saved chunk 563/1221
# progress saved chunk 564/1221
# progress saved chunk 565/1221
# progress saved chunk 566/1221
# progress saved chunk 567/1221
# progress saved chunk 568/1221
# progress saved chunk 569/1221
# progress saved chunk 570/1221
# progress saved chunk 571/1221
# progress saved chunk 572/1221
# progress saved chunk 573/1221
# progress saved chunk 574/1221
# progress saved chunk 575/1221
# progress saved chunk 576/1221
# progress saved chunk 577/1221
# progress saved chunk 578/1221
# progress saved chunk 579/1221
# progress saved chunk 580/1221
# progress saved chunk 581/1221
# progress saved chunk 582/1221
# progress saved chunk 583/1221
# progress saved chunk 584/1221
# progress saved chunk 585/1221
# progress saved chunk 586/1221
# progress saved chunk 587/1221
# progress saved chunk 588/1221
# progress saved chunk 589/1221
# progress saved chunk 590/1221
# progress saved chunk 591/1221
# progress saved chunk 592/1221
# progress saved chunk 593/1221
# progress saved chunk 594/1221
# progress saved chunk 595/1221
# progress saved chunk 596/1221
# progress saved chunk 597/1221
# progress saved chunk 598/1221
# progress saved chunk 599/1221
# progress saved chunk 600/1221
# progress saved chunk 601/1221
# progress saved chunk 602/1221
# progress saved chunk 603/1221
# progress saved chunk 604/1221
# progress saved chunk 605/1221
# progress saved chunk 606/1221
# progress saved chunk 607/1221
# progress saved chunk 608/1221
# progress saved chunk 609/1221
# progress saved chunk 610/1221
# progress saved chunk 611/1221
# progress saved chunk 612/1221
# progress saved chunk 613/1221
# progress saved chunk 614/1221
# progress saved chunk 615/1221
# progress saved chunk 616/1221
# progress saved chunk 617/1221
# progress saved chunk 618/1221
# progress saved chunk 619/1221
# progress saved chunk 620/1221
# progress saved chunk 621/1221
# progress saved chunk 622/1221
# progress saved chunk 623/1221
# progress saved chunk 624/1221
# progress saved chunk 625/1221
# progress saved chunk 626/1221
# progress saved chunk 627/1221
# progress saved chunk 628/1221
# progress saved chunk 629/1221
# progress saved chunk 630/1221
# progress saved chunk 631/1221
# progress saved chunk 632/1221
# progress saved chunk 633/1221
# progress saved chunk 634/1221
# progress saved chunk 635/1221
# progress saved chunk 636/1221
# progress saved chunk 637/1221
# progress saved chunk 638/1221
# progress saved chunk 639/1221
# progress saved chunk 640/1221
# progress saved chunk 641/1221
# progress saved chunk 642/1221
# progress saved chunk 643/1221
# progress saved chunk 644/1221
# progress saved chunk 645/1221
# progress saved chunk 646/1221
# progress saved chunk 647/1221
# progress saved chunk 648/1221
# progress saved chunk 649/1221
# progress saved chunk 650/1221
# progress saved chunk 651/1221
# progress saved chunk 652/1221
# progress saved chunk 653/1221
# progress saved chunk 654/1221
# progress saved chunk 655/1221
# progress saved chunk 656/1221
# progress saved chunk 657/1221
# progress saved chunk 658/1221
# progress saved chunk 659/1221
# progress saved chunk 660/1221
# progress saved chunk 661/1221
# progress saved chunk 662/1221
# progress saved chunk 663/1221
# progress saved chunk 664/1221
# progress saved chunk 665/1221
# progress saved chunk 666/1221
# progress saved chunk 667/1221
# progress saved chunk 668/1221
# progress saved chunk 669/1221
# progress saved chunk 670/1221
# progress saved chunk 671/1221
# progress saved chunk 672/1221
# progress saved chunk 673/1221
# progress saved chunk 674/1221
# progress saved chunk 675/1221
# progress saved chunk 676/1221
# progress saved chunk 677/1221
# progress saved chunk 678/1221
# progress saved chunk 679/1221
# progress saved chunk 680/1221
# progress saved chunk 681/1221
# progress saved chunk 682/1221
# progress saved chunk 683/1221
# progress saved chunk 684/1221
# progress saved chunk 685/1221
# progress saved chunk 686/1221
# progress saved chunk 687/1221
# progress saved chunk 688/1221
# progress saved chunk 689/1221
# progress saved chunk 690/1221
# progress saved chunk 691/1221
# progress saved chunk 692/1221
# progress saved chunk 693/1221
# progress saved chunk 694/1221
# progress saved chunk 695/1221
# progress saved chunk 696/1221
# progress saved chunk 697/1221
# progress saved chunk 698/1221
# progress saved chunk 699/1221
# progress saved chunk 700/1221
# progress saved chunk 701/1221
# progress saved chunk 702/1221
# progress saved chunk 703/1221
# progress saved chunk 704/1221
# progress saved chunk 705/1221
# progress saved chunk 706/1221
# progress saved chunk 707/1221
# progress saved chunk 708/1221
# progress saved chunk 709/1221
# progress saved chunk 710/1221
# progress saved chunk 711/1221
# progress saved chunk 712/1221
# progress saved chunk 713/1221
# progress saved chunk 714/1221
# progress saved chunk 715/1221
# progress saved chunk 716/1221
# progress saved chunk 717/1221
# progress saved chunk 718/1221
# progress saved chunk 719/1221
# progress saved chunk 720/1221
# progress saved chunk 721/1221
# progress saved chunk 722/1221
# progress saved chunk 723/1221
# progress saved chunk 724/1221
# progress saved chunk 725/1221
# progress saved chunk 726/1221
# progress saved chunk 727/1221
# progress saved chunk 728/1221
# progress saved chunk 729/1221
# progress saved chunk 730/1221
# progress saved chunk 731/1221
# progress saved chunk 732/1221
# progress saved chunk 733/1221
# progress saved chunk 734/1221
# progress saved chunk 735/1221
# progress saved chunk 736/1221
# progress saved chunk 737/1221
# progress saved chunk 738/1221
# progress saved chunk 739/1221
# progress saved chunk 740/1221
# progress saved chunk 741/1221
# progress saved chunk 742/1221
# progress saved chunk 743/1221
# progress saved chunk 744/1221
# progress saved chunk 745/1221
# progress saved chunk 746/1221
# progress saved chunk 747/1221
# progress saved chunk 748/1221
# progress saved chunk 749/1221
# progress saved chunk 750/1221
# progress saved chunk 751/1221
# progress saved chunk 752/1221
# progress saved chunk 753/1221
# progress saved chunk 754/1221
# progress saved chunk 755/1221
# progress saved chunk 756/1221
# progress saved chunk 757/1221
# progress saved chunk 758/1221
# progress saved chunk 759/1221
# progress saved chunk 760/1221
# progress saved chunk 761/1221
# progress saved chunk 762/1221
# progress saved chunk 763/1221
# progress saved chunk 764/1221
# progress saved chunk 765/1221
# progress saved chunk 766/1221
# progress saved chunk 767/1221
# progress saved chunk 768/1221
# progress saved chunk 769/1221
# progress saved chunk 770/1221
# progress saved chunk 771/1221
# progress saved chunk 772/1221
# progress saved chunk 773/1221
# progress saved chunk 774/1221
# progress saved chunk 775/1221
# progress saved chunk 776/1221
# progress saved chunk 777/1221
# progress saved chunk 778/1221
# progress saved chunk 779/1221
# progress saved chunk 780/1221
# progress saved chunk 781/1221
# progress saved chunk 782/1221
# progress saved chunk 783/1221
# progress saved chunk 784/1221
# progress saved chunk 785/1221
# progress saved chunk 786/1221
# progress saved chunk 787/1221
# progress saved chunk 788/1221
# progress saved chunk 789/1221
# progress saved chunk 790/1221
# progress saved chunk 791/1221
# progress saved chunk 792/1221
# progress saved chunk 793/1221
# progress saved chunk 794/1221
# progress saved chunk 795/1221
# progress saved chunk 796/1221
# progress saved chunk 797/1221
# progress saved chunk 798/1221
# progress saved chunk 799/1221
# progress saved chunk 800/1221
# progress saved chunk 801/1221
# progress saved chunk 802/1221
# progress saved chunk 803/1221
# progress saved chunk 804/1221
# progress saved chunk 805/1221
# progress saved chunk 806/1221
# progress saved chunk 807/1221
# progress saved chunk 808/1221
# progress saved chunk 809/1221
# progress saved chunk 810/1221
# progress saved chunk 811/1221
# progress saved chunk 812/1221
# progress saved chunk 813/1221
# progress saved chunk 814/1221
# progress saved chunk 815/1221
# progress saved chunk 816/1221
# progress saved chunk 817/1221
# progress saved chunk 818/1221
# progress saved chunk 819/1221
# progress saved chunk 820/1221
# progress saved chunk 821/1221
# progress saved chunk 822/1221
# progress saved chunk 823/1221
# progress saved chunk 824/1221
# progress saved chunk 825/1221
# progress saved chunk 826/1221
# progress saved chunk 827/1221
# progress saved chunk 828/1221
# progress saved chunk 829/1221
# progress saved chunk 830/1221
# progress saved chunk 831/1221
# progress saved chunk 832/1221
# progress saved chunk 833/1221
# progress saved chunk 834/1221
# progress saved chunk 835/1221
# progress saved chunk 836/1221
# progress saved chunk 837/1221
# progress saved chunk 838/1221
# progress saved chunk 839/1221
# progress saved chunk 840/1221
# progress saved chunk 841/1221
# progress saved chunk 842/1221
# progress saved chunk 843/1221
# progress saved chunk 844/1221
# progress saved chunk 845/1221
# progress saved chunk 846/1221
# progress saved chunk 847/1221
# progress saved chunk 848/1221
# progress saved chunk 849/1221
# progress saved chunk 850/1221
# progress saved chunk 851/1221
# progress saved chunk 852/1221
# progress saved chunk 853/1221
# progress saved chunk 854/1221
# progress saved chunk 855/1221
# progress saved chunk 856/1221
# progress saved chunk 857/1221
# progress saved chunk 858/1221
# progress saved chunk 859/1221
# progress saved chunk 860/1221
# progress saved chunk 861/1221
# progress saved chunk 862/1221
# progress saved chunk 863/1221
# progress saved chunk 864/1221
# progress saved chunk 865/1221
# progress saved chunk 866/1221
# progress saved chunk 867/1221
# progress saved chunk 868/1221
# progress saved chunk 869/1221
# progress saved chunk 870/1221
# progress saved chunk 871/1221
# progress saved chunk 872/1221
# progress saved chunk 873/1221
# progress saved chunk 874/1221
# progress saved chunk 875/1221
# progress saved chunk 876/1221
# progress saved chunk 877/1221
# progress saved chunk 878/1221
# progress saved chunk 879/1221
# progress saved chunk 880/1221
# progress saved chunk 881/1221
# progress saved chunk 882/1221
# progress saved chunk 883/1221
# progress saved chunk 884/1221
# progress saved chunk 885/1221
# progress saved chunk 886/1221
# progress saved chunk 887/1221
# progress saved chunk 888/1221
# progress saved chunk 889/1221
# progress saved chunk 890/1221
# progress saved chunk 891/1221
# progress saved chunk 892/1221
# progress saved chunk 893/1221
# progress saved chunk 894/1221
# progress saved chunk 895/1221
# progress saved chunk 896/1221
# progress saved chunk 897/1221
# progress saved chunk 898/1221
# progress saved chunk 899/1221
# progress saved chunk 900/1221
# progress saved chunk 901/1221
# progress saved chunk 902/1221
# progress saved chunk 903/1221
# progress saved chunk 904/1221
# progress saved chunk 905/1221
# progress saved chunk 906/1221
# progress saved chunk 907/1221
# progress saved chunk 908/1221
# progress saved chunk 909/1221
# progress saved chunk 910/1221
# progress saved chunk 911/1221
# progress saved chunk 912/1221
# progress saved chunk 913/1221
# progress saved chunk 914/1221
# progress saved chunk 915/1221
# progress saved chunk 916/1221
# progress saved chunk 917/1221
# progress saved chunk 918/1221
# progress saved chunk 919/1221
# progress saved chunk 920/1221
# progress saved chunk 921/1221
# progress saved chunk 922/1221
# progress saved chunk 923/1221
# progress saved chunk 924/1221
# progress saved chunk 925/1221
# progress saved chunk 926/1221
# progress saved chunk 927/1221
# progress saved chunk 928/1221
# progress saved chunk 929/1221
# progress saved chunk 930/1221
# progress saved chunk 931/1221
# progress saved chunk 932/1221
# progress saved chunk 933/1221
# progress saved chunk 934/1221
# progress saved chunk 935/1221
# progress saved chunk 936/1221
# progress saved chunk 937/1221
# progress saved chunk 938/1221
# progress saved chunk 939/1221
# progress saved chunk 940/1221
# progress saved chunk 941/1221
# progress saved chunk 942/1221
# progress saved chunk 943/1221
# progress saved chunk 944/1221
# progress saved chunk 945/1221
# progress saved chunk 946/1221
# progress saved chunk 947/1221
# progress saved chunk 948/1221
# progress saved chunk 949/1221
# progress saved chunk 950/1221
# progress saved chunk 951/1221
# progress saved chunk 952/1221
# progress saved chunk 953/1221
# progress saved chunk 954/1221
# progress saved chunk 955/1221
# progress saved chunk 956/1221
# progress saved chunk 957/1221
# progress saved chunk 958/1221
# progress saved chunk 959/1221
# progress saved chunk 960/1221
# progress saved chunk 961/1221
# progress saved chunk 962/1221
# progress saved chunk 963/1221
# progress saved chunk 964/1221
# progress saved chunk 965/1221
# progress saved chunk 966/1221
# progress saved chunk 967/1221
# progress saved chunk 968/1221
# progress saved chunk 969/1221
# progress saved chunk 970/1221
# progress saved chunk 971/1221
# progress saved chunk 972/1221
# progress saved chunk 973/1221
# progress saved chunk 974/1221
# progress saved chunk 975/1221
# progress saved chunk 976/1221
# progress saved chunk 977/1221
# progress saved chunk 978/1221
# progress saved chunk 979/1221
# progress saved chunk 980/1221
# progress saved chunk 981/1221
# progress saved chunk 982/1221
# progress saved chunk 983/1221
# progress saved chunk 984/1221
# progress saved chunk 985/1221
# progress saved chunk 986/1221
# progress saved chunk 987/1221
# progress saved chunk 988/1221
# progress saved chunk 989/1221
# progress saved chunk 990/1221
# progress saved chunk 991/1221
# progress saved chunk 992/1221
# progress saved chunk 993/1221
# progress saved chunk 994/1221
# progress saved chunk 995/1221
# progress saved chunk 996/1221
# progress saved chunk 997/1221
# progress saved chunk 998/1221
# progress saved chunk 999/1221
# progress saved chunk 1000/1221
# progress saved chunk 1001/1221
# progress saved chunk 1002/1221
# progress saved chunk 1003/1221
# progress saved chunk 1004/1221
# progress saved chunk 1005/1221
# progress saved chunk 1006/1221
# progress saved chunk 1007/1221
# progress saved chunk 1008/1221
# progress saved chunk 1009/1221
# progress saved chunk 1010/1221
# progress saved chunk 1011/1221
# progress saved chunk 1012/1221
# progress saved chunk 1013/1221
# progress saved chunk 1014/1221
# progress saved chunk 1015/1221
# progress saved chunk 1016/1221
# progress saved chunk 1017/1221
# progress saved chunk 1018/1221
# progress saved chunk 1019/1221
# progress saved chunk 1020/1221
# progress saved chunk 1021/1221
# progress saved chunk 1022/1221
# progress saved chunk 1023/1221
# progress saved chunk 1024/1221
# progress saved chunk 1025/1221
# progress saved chunk 1026/1221
# progress saved chunk 1027/1221
# progress saved chunk 1028/1221
# progress saved chunk 1029/1221
# progress saved chunk 1030/1221
# progress saved chunk 1031/1221
# progress saved chunk 1032/1221
# progress saved chunk 1033/1221
# progress saved chunk 1034/1221
# progress saved chunk 1035/1221
# progress saved chunk 1036/1221
# progress saved chunk 1037/1221
# progress saved chunk 1038/1221
# progress saved chunk 1039/1221
# progress saved chunk 1040/1221
# progress saved chunk 1041/1221
# progress saved chunk 1042/1221
# progress saved chunk 1043/1221
# progress saved chunk 1044/1221
# progress saved chunk 1045/1221
# progress saved chunk 1046/1221
# progress saved chunk 1047/1221
# progress saved chunk 1048/1221
# progress saved chunk 1049/1221
# progress saved chunk 1050/1221
# progress saved chunk 1051/1221
# progress saved chunk 1052/1221
# progress saved chunk 1053/1221
# progress saved chunk 1054/1221
# progress saved chunk 1055/1221
# progress saved chunk 1056/1221
# progress saved chunk 1057/1221
# progress saved chunk 1058/1221
# progress saved chunk 1059/1221
# progress saved chunk 1060/1221
# progress saved chunk 1061/1221
# progress saved chunk 1062/1221
# progress saved chunk 1063/1221
# progress saved chunk 1064/1221
# progress saved chunk 1065/1221
# progress saved chunk 1066/1221
# progress saved chunk 1067/1221
# progress saved chunk 1068/1221
# progress saved chunk 1069/1221
# progress saved chunk 1070/1221
# progress saved chunk 1071/1221
# progress saved chunk 1072/1221
# progress saved chunk 1073/1221
# progress saved chunk 1074/1221
# progress saved chunk 1075/1221
# progress saved chunk 1076/1221
# progress saved chunk 1077/1221
# progress saved chunk 1078/1221
# progress saved chunk 1079/1221
# progress saved chunk 1080/1221
# progress saved chunk 1081/1221
# progress saved chunk 1082/1221
# progress saved chunk 1083/1221
# progress saved chunk 1084/1221
# progress saved chunk 1085/1221
# progress saved chunk 1086/1221
# progress saved chunk 1087/1221
# progress saved chunk 1088/1221
# progress saved chunk 1089/1221
# progress saved chunk 1090/1221
# progress saved chunk 1091/1221
# progress saved chunk 1092/1221
# progress saved chunk 1093/1221
# progress saved chunk 1094/1221
# progress saved chunk 1095/1221
# progress saved chunk 1096/1221
# progress saved chunk 1097/1221
# progress saved chunk 1098/1221
# progress saved chunk 1099/1221
# progress saved chunk 1100/1221
# progress saved chunk 1101/1221
# progress saved chunk 1102/1221
# progress saved chunk 1103/1221
# progress saved chunk 1104/1221
# progress saved chunk 1105/1221
# progress saved chunk 1106/1221
# progress saved chunk 1107/1221
# progress saved chunk 1108/1221
# progress saved chunk 1109/1221
# progress saved chunk 1110/1221
# progress saved chunk 1111/1221
# progress saved chunk 1112/1221
# progress saved chunk 1113/1221
# progress saved chunk 1114/1221
# progress saved chunk 1115/1221
# progress saved chunk 1116/1221
# progress saved chunk 1117/1221
# progress saved chunk 1118/1221
# progress saved chunk 1119/1221
# progress saved chunk 1120/1221
# progress saved chunk 1121/1221
# progress saved chunk 1122/1221
# progress saved chunk 1123/1221
# progress saved chunk 1124/1221
# progress saved chunk 1125/1221
# progress saved chunk 1126/1221
# progress saved chunk 1127/1221
# progress saved chunk 1128/1221
# progress saved chunk 1129/1221
# progress saved chunk 1130/1221
# progress saved chunk 1131/1221
# progress saved chunk 1132/1221
# progress saved chunk 1133/1221
# progress saved chunk 1134/1221
# progress saved chunk 1135/1221
# progress saved chunk 1136/1221
# progress saved chunk 1137/1221
# progress saved chunk 1138/1221
# progress saved chunk 1139/1221
# progress saved chunk 1140/1221
# progress saved chunk 1141/1221
# progress saved chunk 1142/1221
# progress saved chunk 1143/1221
# progress saved chunk 1144/1221
# progress saved chunk 1145/1221
# progress saved chunk 1146/1221
# progress saved chunk 1147/1221
# progress saved chunk 1148/1221
# progress saved chunk 1149/1221
# progress saved chunk 1150/1221
# progress saved chunk 1151/1221
# progress saved chunk 1152/1221
# progress saved chunk 1153/1221
# progress saved chunk 1154/1221
# progress saved chunk 1155/1221
# progress saved chunk 1156/1221
# progress saved chunk 1157/1221
# progress saved chunk 1158/1221
# progress saved chunk 1159/1221
# progress saved chunk 1160/1221
# progress saved chunk 1161/1221
# progress saved chunk 1162/1221
# progress saved chunk 1163/1221
# progress saved chunk 1164/1221
# progress saved chunk 1165/1221
# progress saved chunk 1166/1221
# progress saved chunk 1167/1221
# progress saved chunk 1168/1221
# progress saved chunk 1169/1221
# progress saved chunk 1170/1221
# progress saved chunk 1171/1221
# progress saved chunk 1172/1221
# progress saved chunk 1173/1221
# progress saved chunk 1174/1221
# progress saved chunk 1175/1221
# progress saved chunk 1176/1221
# progress saved chunk 1177/1221
# progress saved chunk 1178/1221
# progress saved chunk 1179/1221
# progress saved chunk 1180/1221
# progress saved chunk 1181/1221
# progress saved chunk 1182/1221
# progress saved chunk 1183/1221
# progress saved chunk 1184/1221
# progress saved chunk 1185/1221
# progress saved chunk 1186/1221
# progress saved chunk 1187/1221
# progress saved chunk 1188/1221
# progress saved chunk 1189/1221
# progress saved chunk 1190/1221
# progress saved chunk 1191/1221
# progress saved chunk 1192/1221
# progress saved chunk 1193/1221
# progress saved chunk 1194/1221
# progress saved chunk 1195/1221
# progress saved chunk 1196/1221
# progress saved chunk 1197/1221
# progress saved chunk 1198/1221
# progress saved chunk 1199/1221
# progress saved chunk 1200/1221
# progress saved chunk 1201/1221
# progress saved chunk 1202/1221
# progress saved chunk 1203/1221
# progress saved chunk 1204/1221
# progress saved chunk 1205/1221
# progress saved chunk 1206/1221
# progress saved chunk 1207/1221
# progress saved chunk 1208/1221
# 1 preview tracks not available for From the Uncharted Island by Xiphea
# progress saved chunk 1209/1221
# progress saved chunk 1210/1221
# progress saved chunk 1211/1221
# progress saved chunk 1212/1221
# progress saved chunk 1213/1221
# progress saved chunk 1214/1221
# 15 preview tracks not available for Lyne Van Jou Lyf by Morne
# progress saved chunk 1215/1221
# progress saved chunk 1216/1221
# progress saved chunk 1217/1221
# progress saved chunk 1218/1221
# progress saved chunk 1219/1221
# progress saved chunk 1220/1221
# Album scraping completed

# %%
dct = {
    'id':[],
    'acousticness': [],
    'danceability': [],
    'duration_ms': [],
    'energy': [],
    'instrumentalness':[],
    'key': [],
    'liveness': [],
    'loudness_dB': [],
    'mode': [],
    'speechiness': [],
    'tempo':[],
    'time_signature':[],
    'valence': []
}

df = pd.DataFrame(dct)
df.to_csv('audio_features.csv', index=False)

# %%
# Function to process audio features for an album
def process_features(features):
    if features is None:
        print("Error: No data returned from Spotify API call")
        return {}  # Return an empty dictionary
    else:
        # Extract all specified keys from the list of dictionaries
        desired_keys = [
            'id', 'acousticness', 'danceability', 'duration_ms', 'energy',
            'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
            'speechiness', 'tempo', 'time_signature', 'valence'
        ]

        # Filter out null values and extract features
        valid_features = [item for item in features if item is not None]
        
        result_dict = {
            key: [item[key] for item in valid_features if item['id'] not in processed_features] 
            for key in desired_keys
        }

        time.sleep(0.5)  # Add a short delay between album downloads
        return result_dict

# Read track IDs from CSV file
tracks = pd.read_csv('tracks.csv')

# Read processed features from CSV file
processed = pd.read_csv('audio_features.csv')
processed_features = set(processed['id'])
print(f'nr of processed songs = {len(processed_features)}')
# Define a dictionary to store audio features

# Decorator for rate limiting
@sleep_and_retry
@limits(calls=100, period=60)  # Adjust rate limit as per Spotify API limits
def call_spotify_api(func, *args, **kwargs):
    try:
        return func(*args, **kwargs)
    except requests.exceptions.Timeout:
        print("Request timed out, retrying...")
        time.sleep(10)  # Wait for 10 seconds before retrying
        return call_spotify_api(func, *args, **kwargs)
    
dct = {}
c=0
chunklist = [tracks['track_id'][i: i + 100] for i in range(2000, len(tracks['track_id']), 100)]
for index, chunk in enumerate(chunklist):
    unprocessed_chunk = [track_id for track_id in chunk if track_id not in processed_features]
    if unprocessed_chunk:
    
        features = call_spotify_api(sp.audio_features, unprocessed_chunk)
        dct = (process_features(features))
        print(f'Progress saved chunk {index+1}/{len(chunklist)}, length = {len(unprocessed_chunk)}')
        # Save the DataFrame to CSV, appending to the existing file
        featuredf = pd.DataFrame(dct)
        featuredf.drop_duplicates(subset=['id'], inplace=True)
        featuredf.to_csv('audio_features.csv', mode='a', index=False, header=not os.path.exists('audio_features.csv'))

        # Reset the dct dictionary to avoid duplicates in the next chunk
        dct = {}
    else:
        continue

  
print('Feature scraping completed')
# Out:
# nr of processed songs = 276792
# Progress saved chunk 11/2751, length = 2
# Progress saved chunk 25/2751, length = 1
# Progress saved chunk 30/2751, length = 1
# Progress saved chunk 40/2751, length = 1
# Progress saved chunk 97/2751, length = 1
# Progress saved chunk 120/2751, length = 1
# Progress saved chunk 127/2751, length = 1
# Progress saved chunk 151/2751, length = 1
# Progress saved chunk 191/2751, length = 1
# Progress saved chunk 217/2751, length = 1
# Progress saved chunk 235/2751, length = 1
# Progress saved chunk 254/2751, length = 1
# Progress saved chunk 256/2751, length = 1
# Progress saved chunk 325/2751, length = 1
# Progress saved chunk 355/2751, length = 1
# Progress saved chunk 356/2751, length = 1
# Progress saved chunk 380/2751, length = 2
# Progress saved chunk 485/2751, length = 2
# Progress saved chunk 502/2751, length = 1
# Progress saved chunk 503/2751, length = 1
# Progress saved chunk 541/2751, length = 1
# Progress saved chunk 544/2751, length = 1
# Progress saved chunk 603/2751, length = 1
# Progress saved chunk 620/2751, length = 3
# Progress saved chunk 628/2751, length = 1
# Progress saved chunk 714/2751, length = 1
# Progress saved chunk 716/2751, length = 1
# Progress saved chunk 724/2751, length = 1
# Progress saved chunk 735/2751, length = 1
# Progress saved chunk 805/2751, length = 1
# Progress saved chunk 823/2751, length = 1
# Progress saved chunk 825/2751, length = 1
# Progress saved chunk 857/2751, length = 1
# Progress saved chunk 865/2751, length = 2
# Progress saved chunk 875/2751, length = 1
# Progress saved chunk 917/2751, length = 4
# Progress saved chunk 918/2751, length = 10
# Progress saved chunk 932/2751, length = 1
# Progress saved chunk 937/2751, length = 5
# Progress saved chunk 938/2751, length = 26
# Progress saved chunk 939/2751, length = 10
# Progress saved chunk 953/2751, length = 1
# Progress saved chunk 956/2751, length = 1
# Progress saved chunk 961/2751, length = 2
# Progress saved chunk 965/2751, length = 1
# Progress saved chunk 972/2751, length = 2
# Progress saved chunk 991/2751, length = 1
# Progress saved chunk 992/2751, length = 1
# Progress saved chunk 1000/2751, length = 5
# Progress saved chunk 1001/2751, length = 17
# Progress saved chunk 1018/2751, length = 1
# Progress saved chunk 1045/2751, length = 1
# Progress saved chunk 1055/2751, length = 8
# Progress saved chunk 1195/2751, length = 1
# Progress saved chunk 1207/2751, length = 1
# Progress saved chunk 1277/2751, length = 3
# Progress saved chunk 1377/2751, length = 1
# Progress saved chunk 1468/2751, length = 1
# Progress saved chunk 1514/2751, length = 1
# Progress saved chunk 1540/2751, length = 1
# Progress saved chunk 1547/2751, length = 1
# Progress saved chunk 1587/2751, length = 1
# Progress saved chunk 1598/2751, length = 1
# Progress saved chunk 1600/2751, length = 1
# Progress saved chunk 1661/2751, length = 1
# Progress saved chunk 1664/2751, length = 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 53
#      50 if unprocessed_chunk:
#      52     features = call_spotify_api(sp.audio_features, unprocessed_chunk)
# ---> 53     dct = (process_features(features))
#      54     print(f'Progress saved chunk {index+1}/{len(chunklist)}, length = {len(unprocessed_chunk)}')
#      55     # Save the DataFrame to CSV, appending to the existing file
#
# Cell In[7], line 22, in process_features(features)
#      15 valid_features = [item for item in features if item is not None]
#      17 result_dict = {
#      18     key: [item[key] for item in valid_features if item['id'] not in processed_features]
#      19     for key in desired_keys
#      20 }
# ---> 22 time.sleep(0.5)  # Add a short delay between album downloads
#      23 return result_dict
#
# KeyboardInterrupt:
